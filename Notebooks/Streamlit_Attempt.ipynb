# %% [markdown]
# # Imports

# %%
import pandas as pd

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from collections import Counter

# %% [markdown]
# # Dataset Inspection

# %%
# Load the cleaned data
df = pd.read_csv('clean_df.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2892 entries, 0 to 2891
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   quantity         2586 non-null   float64
#  1   unit             2524 non-null   object
#  2   ingredient       2890 non-null   object
#  3   ingredient_step  2892 non-null   int64
#  4   recipe_id        2892 non-null   int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 113.1+ KB

# %%
# Group by recipe_id and aggregate ingredients into lists
grouped_df = df.groupby('recipe_id')['ingredient'].apply(list).reset_index()

# Display grouped DataFrame
grouped_df
# Out:
#      recipe_id                                         ingredient
# 0            0  [dark rum, lime juice, sugar, angostura, perno...
# 1            1  [silver tequila, marie brizard creme de cacao,...
# 2            2  [gin, mari brizard white creme de cacao, lille...
# 3            3                             [pernod, sugar, water]
# 4            4  [gold tequila, gold rum, grapefruit juice, pin...
# ..         ...                                                ...
# 650        650      [light rum, galliano, triple sec, lime juice]
# 651        651  [dark rum, light rum, tia maria, orange juice,...
# 652        652     [vodka, galliano, lime juice, pineapple juice]
# 653        653        [yellow chartreuse, pernod, apricot brandy]
# 654        654  [rye whiskey, lemon juice, pineapple syrup, do...
#
# [655 rows x 2 columns]

# %%
# Extract the list of lists of ingredients
recipes = grouped_df['ingredient'].tolist()

# Get the list of all unique ingredients
all_ingredients = df['ingredient'].unique().tolist()

# Use MultiLabelBinarizer to encode the ingredients
mlb = MultiLabelBinarizer(classes=all_ingredients)
encoded_recipes = mlb.fit_transform(recipes)

# Create a DataFrame for easier manipulation
encoded_df = pd.DataFrame(encoded_recipes, columns=mlb.classes_)

# %%
encoded_df.shape
# Out:
# (655, 389)

# %% [markdown]
# # Outline:

# %% [markdown]
# Model Building:

# %% [markdown]
# Our model architecture is:
#
# l0: 389 (amount of unique ingredients)
#
# hidden layers:          relu
#
# L :            sigmoid   , 389

# %%
input_dim = len(all_ingredients)  # Number of unique ingredients

# %%
model = Sequential()
model.add(Dense(units=128, input_dim=input_dim, activation='relu'))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=input_dim, activation='sigmoid'))  # Output layer with sigmoid activation

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# attempt at at a 2nd model, larger architecture since 389 param

input_dim = len(all_ingredients)  # Number of unique ingredients

model = Sequential()
model.add(Dense(units=512, input_dim=input_dim, activation='relu'))  # First hidden layer
model.add(Dense(units=256, activation='relu'))  # Second hidden layer
model.add(Dense(units=128, activation='relu'))  # Second hidden layer
model.add(Dense(units=input_dim, activation='sigmoid'))  # Output layer

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Print model summary to verify the architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               199680
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 389)               50181
#
# =================================================================
# Total params: 414,085
# Trainable params: 414,085
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Attemping dropout layers
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Define the model
model = Sequential()
model.add(Dropout(0.1, input_shape=(input_dim,)))  # Dropout layer for the input layer
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))  # Dropout layer for hidden layers
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))  # Dropout layer for hidden layers
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))  # Dropout layer for hidden layers
model.add(Dense(input_dim, activation='sigmoid'))  # Output layer for multi-label classification


# Compile the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.summary()

# %% [markdown]
# Model Training:

# %%
X = encoded_df.values  # Input features (binary vectors of ingredients)
y = encoded_df.values  # Target labels (same as input for multi-label classification)

#model.fit(X, y, epochs=20, batch_size=50, validation_split=0.2)

# %% [markdown]
# Generating New Recipes:
#
# Start with a seed ingredient or set of ingredients.
# Use the trained model to predict additional ingredients.

# %%
model.fit(X, y, epochs=50, batch_size=50, validation_split=0.2)

seed_ingredients = ['vodka']  # Example seed ingredients
seed_vector = mlb.transform([seed_ingredients])[0]

predicted_probabilities = model.predict(seed_vector.reshape(1, -1))
predicted_ingredients = mlb.inverse_transform((predicted_probabilities > 0.00001).astype(int))[0]

generated_recipe = list(set(seed_ingredients + list(predicted_ingredients)))
print("Generated Recipe:", generated_recipe)
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 25ms/step - loss: 0.6460 - accuracy: 0.0000e+00 - val_loss: 0.4913 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 11/11 [==============================] - 0s 10ms/step - loss: 0.2574 - accuracy: 0.0000e+00 - val_loss: 0.0754 - val_accuracy: 0.0076
# Epoch 3/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0792 - accuracy: 0.1775 - val_loss: 0.0763 - val_accuracy: 0.2290
# Epoch 4/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0686 - accuracy: 0.1374 - val_loss: 0.0589 - val_accuracy: 0.0992
# Epoch 5/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0545 - accuracy: 0.1355 - val_loss: 0.0543 - val_accuracy: 0.2214
# Epoch 6/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0501 - accuracy: 0.2863 - val_loss: 0.0532 - val_accuracy: 0.2595
# Epoch 7/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0488 - accuracy: 0.1756 - val_loss: 0.0526 - val_accuracy: 0.3359
# Epoch 8/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0479 - accuracy: 0.3779 - val_loss: 0.0521 - val_accuracy: 0.4046
# Epoch 9/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0474 - accuracy: 0.4103 - val_loss: 0.0517 - val_accuracy: 0.3740
# Epoch 10/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 0.4198 - val_loss: 0.0515 - val_accuracy: 0.4046
# Epoch 11/50
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0464 - accuracy: 0.4218 - val_loss: 0.0514 - val_accuracy: 0.4046
# Epoch 12/50
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0460 - accuracy: 0.4408 - val_loss: 0.0512 - val_accuracy: 0.4198
# Epoch 13/50
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0457 - accuracy: 0.4389 - val_loss: 0.0509 - val_accuracy: 0.4275
# Epoch 14/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0453 - accuracy: 0.3779 - val_loss: 0.0508 - val_accuracy: 0.3588
# Epoch 15/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0449 - accuracy: 0.4160 - val_loss: 0.0503 - val_accuracy: 0.4198
# Epoch 16/50
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0444 - accuracy: 0.4752 - val_loss: 0.0501 - val_accuracy: 0.4351
# Epoch 17/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0438 - accuracy: 0.4408 - val_loss: 0.0497 - val_accuracy: 0.4580
# Epoch 18/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0430 - accuracy: 0.5134 - val_loss: 0.0491 - val_accuracy: 0.4885
# Epoch 19/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0422 - accuracy: 0.5229 - val_loss: 0.0484 - val_accuracy: 0.5191
# Epoch 20/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0412 - accuracy: 0.5668 - val_loss: 0.0479 - val_accuracy: 0.5344
# Epoch 21/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0402 - accuracy: 0.5668 - val_loss: 0.0470 - val_accuracy: 0.5344
# Epoch 22/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0391 - accuracy: 0.6050 - val_loss: 0.0462 - val_accuracy: 0.5496
# Epoch 23/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0379 - accuracy: 0.6107 - val_loss: 0.0456 - val_accuracy: 0.5573
# Epoch 24/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0368 - accuracy: 0.6031 - val_loss: 0.0448 - val_accuracy: 0.5573
# Epoch 25/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0355 - accuracy: 0.6145 - val_loss: 0.0439 - val_accuracy: 0.5496
# Epoch 26/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0342 - accuracy: 0.5859 - val_loss: 0.0432 - val_accuracy: 0.5725
# Epoch 27/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0330 - accuracy: 0.5916 - val_loss: 0.0426 - val_accuracy: 0.5802
# Epoch 28/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0316 - accuracy: 0.5935 - val_loss: 0.0416 - val_accuracy: 0.5725
# Epoch 29/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0303 - accuracy: 0.5649 - val_loss: 0.0412 - val_accuracy: 0.5878
# Epoch 30/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.5782 - val_loss: 0.0405 - val_accuracy: 0.5802
# Epoch 31/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0276 - accuracy: 0.5611 - val_loss: 0.0398 - val_accuracy: 0.5649
# Epoch 32/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0262 - accuracy: 0.5611 - val_loss: 0.0395 - val_accuracy: 0.5802
# Epoch 33/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0248 - accuracy: 0.5630 - val_loss: 0.0390 - val_accuracy: 0.5954
# Epoch 34/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0235 - accuracy: 0.5630 - val_loss: 0.0388 - val_accuracy: 0.6260
# Epoch 35/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0222 - accuracy: 0.5687 - val_loss: 0.0385 - val_accuracy: 0.5878
# Epoch 36/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0209 - accuracy: 0.5553 - val_loss: 0.0383 - val_accuracy: 0.6031
# Epoch 37/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0197 - accuracy: 0.5782 - val_loss: 0.0383 - val_accuracy: 0.6031
# Epoch 38/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0186 - accuracy: 0.5553 - val_loss: 0.0384 - val_accuracy: 0.5878
# Epoch 39/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0174 - accuracy: 0.5763 - val_loss: 0.0385 - val_accuracy: 0.6031
# Epoch 40/50
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0164 - accuracy: 0.5687 - val_loss: 0.0389 - val_accuracy: 0.5649
# Epoch 41/50
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0153 - accuracy: 0.5534 - val_loss: 0.0385 - val_accuracy: 0.5802
# Epoch 42/50
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0143 - accuracy: 0.5534 - val_loss: 0.0390 - val_accuracy: 0.5649
# Epoch 43/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0132 - accuracy: 0.5401 - val_loss: 0.0390 - val_accuracy: 0.5649
# Epoch 44/50
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0122 - accuracy: 0.5553 - val_loss: 0.0400 - val_accuracy: 0.5802
# Epoch 45/50
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0113 - accuracy: 0.5344 - val_loss: 0.0402 - val_accuracy: 0.5573
# Epoch 46/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0104 - accuracy: 0.5382 - val_loss: 0.0405 - val_accuracy: 0.5649
# Epoch 47/50
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0095 - accuracy: 0.5115 - val_loss: 0.0408 - val_accuracy: 0.5496
# Epoch 48/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0086 - accuracy: 0.5267 - val_loss: 0.0416 - val_accuracy: 0.5191
# Epoch 49/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.5076 - val_loss: 0.0420 - val_accuracy: 0.5649
# Epoch 50/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0071 - accuracy: 0.5076 - val_loss: 0.0429 - val_accuracy: 0.5344
# 1/1 [==============================] - 0s 98ms/step
# Generated Recipe: ['kassatly chtaura orgeat', 'kahlúa', nan, 'vodka', 'rose petals', 'apricot liqueur', 'lillet blanc', 'orange juice', 'baileys irish cream', 'drambuie', 'cherry brandy', 'cognac', 'pastis', 'cucumber spear', 'falernum', 'milk', 'campari', 'hot sauce', 'old tom gin', 'cola', 'chopped green onion', 'pineapple pieces', 'whiskey', 'cubed ripe papaya', 'silver tequila', 'tia maria coffee liqueur', 'pomegranate syrup', 'dry red wine', 'pierre ferrand ambre cognac', 'club soda', 'chambord', 'orange twist', 'blackberries', 'black sambuca', 'mint sprig', 'lillet', 'ice cream', 'absinth', 'red port', 'green cocktail olive', 'coconut rum', 'st. elizabeth allspice dram', 'glass chartreuse', 'grated nutmeg', 'ruby port', 'vermouth', 'white crème de cacao', 'spearmint', 'dry vermouth', 'absinthe', 'butterscotch schnapps', 'sloe gin', 'mandarine napoléon liqueur', 'harveys bristol cream sherry', 'pimms no. 1 cup', 'rye whiskey', 'blue curaçao', 'green crème de menthe', 'marie brizard creme de cacao', 'honey', 'lemon twist', 'watermelon wedge', 'tangerine juice', 'dubonnet rouge', 'orange flower water', 'scotch', 'generic bitters', 'vanilla bean', 'simple', '7-up', 'cachaça', 'bénédictine', 'apple brandy', 'lumps of ice', 'cinnamon stick', 'crème de mûre', 'passion fruit liqueur', '100 proof rhum agricole', 'cranberry juice', 'simple syrup', 'curaao', 'southern comfort', 'vanilla extract', 'sweetened ginger juice', 'maraschino liqueur', 'galliano', 'champagne', '99 bananas liqueur', 'marie brizard apry', 'unsweetened cocoa powder', 'frangelico', 'sugar', 'soda water', 'tangerine slice', 'bokers bitters', 'cucumber slices', 'baileys', 'crème de noyaux', 'curacao', 'maraschino cherries', 'grand marnier', 'crème de cacao', 'demerara syrup', 'irish whiskey', 'ginger-infused vodka', 'guava nectar', 'egg', 'gin', 'vodka citron', 'sweet-and-sour', 'tia maria', 'orange blossom', 'plum wine', 'fernet branca', 'black olive', 'apple juice', 'pineapple rum', 'garnish with montmorency cherries', 'grapefruit juice', 'mari brizard white creme de cacao', 'crème de cassis', 'vieux pontarlier absinthe', 'brandy', 'yellow chartreuse', 'splash soda', 'kosher salt', 'tangerine beverage', 'hot water', 'mandarin  juice', 'lemon wedge', 'crème de framboise', 'nectarine slice', 'orgeat', 'punt e mes', 'raspberries', 'half-and-half', 'strawberry', 'amontillado sherry', 'nutmeg', 'pineapple wedge', 'maraschino cherry', 'pernod', 'kahlua', 'pineapple', 'bigallet china china amer', 'small pat of soft butter', 'celery stalk', 'lime juice', 'diced ripe avocado', 'cold coffee', 'chai', 'orange slice', 'peychauds', 'compass box asyla scotch', 'large eggs', 'rum', 'peach brandy', 'raw egg white', 'selected liquor', 'triple sec', 'dry sake', 'maraschino liquor', 'vanilla-flavored vodka', 'mint', 'peach schnapps', 'blended whiskey', 'cream', 'velvet falernum', 'lemon juice', 'tomato juice', 'liquor', 'dark crème de cacao', 'b&b', 'scotch whiskey', 'dolin rouge', 'pimm’s no. 1', 'pear liqueur', 'water', 'orange curaçao', 'pineapple juice', 'kirsch', 'watermelon', 'gum syrup', 'gomme syrup', 'strawberry syrup', 'chocolate bitters', 'sweet marsala', 'mandarine napoléon', 'whole milk', 'crme de menthe', 'crushed ice', 'averna amaro', 'gold rum', 'prickly pear juice', 'blended scotch', 'cherry heering', 'amaretto', 'crème de menthe', 'applejack', 'orange-flavored vodka', 'oaxacan chocolate powder', 'grenadine', 'seltzer', 'highland malt scotch', 'orange cherry tomatoes', 'damiana liqueur', 'chocolate shavings', 'ground cinnamon', 'glass spirit', 'melon liqueur', 'egg white, beaten', 'calvados', 'strong black coffee', 'passion fruit syrup', 'coconut sorbet ', 'agave nectar', 'jägermeister', 'bacardi cups', 'spiced rum', 'apple cider', 'rhum barbancourt', 'bourbon whiskey', 'peychaud’s bitters', 'st. germain', 'spring water', 'minced clove garlic', 'worcestershire sauce', 'creme de cacao', 'whole strawberry', 'bonne maman raspberry preserves', 'peppermint schnapps',  ...

# %%
# Number of times to generate recipes
num_iterations = 100

# Example seed ingredients
seed_ingredients = ['gin', 'lime juice']
seed_vector = mlb.transform([seed_ingredients])[0]

# List to store generated recipes
generated_recipes = []

for _ in range(num_iterations):
    # Fit the model for one epoch
    model.fit(X, y, epochs=5, batch_size=389, validation_split=0.2, verbose=0)
    
    # Predict probabilities
    predicted_probabilities = model.predict(seed_vector.reshape(1, -1))
    
    # Convert probabilities to ingredients
    predicted_ingredients = mlb.inverse_transform((predicted_probabilities > 0.001).astype(int))[0]
    
    # Generate recipe
    generated_recipe = list(set(seed_ingredients + list(predicted_ingredients)))
    
    # Store the generated recipe as a tuple for easier counting
    generated_recipes.append(tuple(generated_recipe))

# Count the occurrences of each unique recipe
recipe_counts = Counter(generated_recipes)

# Convert to DataFrame
df = pd.DataFrame(recipe_counts.items(), columns=['Recipe', 'Count'])

# Sort by count (optional)
df = df.sort_values(by='Count', ascending=False)

print(df)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
#                                                Recipe  Count
# 23                                  (lime juice, gin)     70
# 22                  (lime juice, orange curaçao, gin)      5
# 18  (lime juice, luxardo maraschino, simple, orang...      3
# 14  (red pepper sauce, lime juice, luxardo marasch...      2
# 1   (lime juice, passion fruit liqueur, peach liqu...      1
# 21  (lime juice, luxardo maraschino, simple, orang...      1
# 20  (lime juice, orange curaçao, luxardo maraschin...      1
# 19  (lime juice, luxardo maraschino, orange curaça...      1
# 17  (red pepper sauce, lime juice, luxardo marasch...      1
# 16  (red pepper sauce, lime juice, luxardo marasch...      1
# 15  (red pepper sauce, lime juice, luxardo marasch...      1
# 13  (red pepper sauce, orange curaçao, lime juice,...      1
# 0   (calvados, lime juice, passion fruit liqueur, ...      1
# 11  (red pepper sauce, lime juice, passion fruit l...      1
# 10  (red pepper sauce, orange curaçao, lime juice,...      1
# 9   (lime juice, passion fruit liqueur, peach liqu...      1
# 8   (lime juice, passion fruit liqueur, peach liqu...      1
# 7   (lime juice, passion fruit liqueur, peach liqu...      1
# 6   (lime juice, passion fruit liqueur, peach liqu...      1
# 5   (lime juice, passion fruit liqueur, peach liqu...      1
# 4   (lime juice, passion fruit liqueur, peach liqu...      1
# 3   (lime juice, passion fruit liqueur, peach liqu...      1
# 2   (lime juice, passion fruit liqueur, peach liqu...      1
# 12  (red pepper sauce, lime juice, passion fruit l...      1

# %%
df['Recipe']
# Out:
# 23                                    (lime juice, gin)
# 22                    (lime juice, orange curaçao, gin)
# 18    (lime juice, luxardo maraschino, simple, orang...
# 14    (red pepper sauce, lime juice, luxardo marasch...
# 1     (lime juice, passion fruit liqueur, peach liqu...
# 21    (lime juice, luxardo maraschino, simple, orang...
# 20    (lime juice, orange curaçao, luxardo maraschin...
# 19    (lime juice, luxardo maraschino, orange curaça...
# 17    (red pepper sauce, lime juice, luxardo marasch...
# 16    (red pepper sauce, lime juice, luxardo marasch...
# 15    (red pepper sauce, lime juice, luxardo marasch...
# 13    (red pepper sauce, orange curaçao, lime juice,...
# 0     (calvados, lime juice, passion fruit liqueur, ...
# 11    (red pepper sauce, lime juice, passion fruit l...
# 10    (red pepper sauce, orange curaçao, lime juice,...
# 9     (lime juice, passion fruit liqueur, peach liqu...
# 8     (lime juice, passion fruit liqueur, peach liqu...
# 7     (lime juice, passion fruit liqueur, peach liqu...
# 6     (lime juice, passion fruit liqueur, peach liqu...
# 5     (lime juice, passion fruit liqueur, peach liqu...
# 4     (lime juice, passion fruit liqueur, peach liqu...
# 3     (lime juice, passion fruit liqueur, peach liqu...
# 2     (lime juice, passion fruit liqueur, peach liqu...
# 12    (red pepper sauce, lime juice, passion fruit l...
# Name: Recipe, dtype: object

# %%
#df['Recipe'][0]

# %%
import numpy as np

# Assuming `predicted_probabilities` is already defined and is a 2D array
# and `mlb` is your MultiLabelBinarizer instance

# Get the indices that would sort each row of the array in descending order
sorted_indices = np.argsort(-predicted_probabilities, axis=1)

# Get the sorted probabilities
sorted_probabilities = np.take_along_axis(predicted_probabilities, sorted_indices, axis=1)

# For each row, map the sorted indices back to the ingredient names
# Assuming you want to do this for the first row in the predictions
top_ingredients_indices = sorted_indices[0]
top_probabilities = sorted_probabilities[0]

# Map these indices back to the ingredient names
top_ingredients = mlb.classes_[top_ingredients_indices]

# Print the top ingredients and their corresponding probabilities
for ingredient, probability in zip(top_ingredients, top_probabilities):
    print(f"Ingredient: {ingredient}, Probability: {probability}")
# Out:
# Ingredient: lime juice, Probability: 0.9999992847442627
# Ingredient: gin, Probability: 0.9999978542327881
# Ingredient: luxardo maraschino, Probability: 0.00014239137817639858
# Ingredient: green chatreuse, Probability: 5.950605918769725e-05
# Ingredient: orange curaçao, Probability: 3.428636773605831e-05
# Ingredient: red pepper sauce, Probability: 1.5466295735677704e-05
# Ingredient: simple, Probability: 1.3398287592281122e-05
# Ingredient: guava nectar, Probability: 1.023065942717949e-05
# Ingredient: galliano, Probability: 8.401830200455151e-06
# Ingredient: clam juice, Probability: 8.120511665765662e-06
# Ingredient: campari, Probability: 6.73890008329181e-06
# Ingredient: peach liqueur, Probability: 5.9380749917181674e-06
# Ingredient: ginger beer, Probability: 5.406109721661778e-06
# Ingredient: orange juice, Probability: 4.796224402525695e-06
# Ingredient: calvados, Probability: 3.872756678902078e-06
# Ingredient: cherry brandy, Probability: 2.8033630314894253e-06
# Ingredient: pomegranate syrup, Probability: 2.6899456315732095e-06
# Ingredient: falernum, Probability: 2.546525138313882e-06
# Ingredient: apricot brandy, Probability: 1.910655782921822e-06
# Ingredient: mint sprig, Probability: 1.7702826653476222e-06
# Ingredient: mount gay eclipse, Probability: 1.4100113503445755e-06
# Ingredient: orange blossom, Probability: 1.3769609950031736e-06
# Ingredient: passion fruit liqueur, Probability: 1.1145987173222238e-06
# Ingredient: cream, Probability: 1.0446777878314606e-06
# Ingredient: club soda, Probability: 9.131850902122096e-07
# Ingredient: mandarine napoléon, Probability: 8.931174306781031e-07
# Ingredient: cointreau, Probability: 7.860677442295128e-07
# Ingredient: rum, Probability: 6.910869956300303e-07
# Ingredient: egg white, Probability: 6.476535077126755e-07
# Ingredient: crème de cassis, Probability: 6.11058226240857e-07
# Ingredient: lemon twist, Probability: 5.826128131047881e-07
# Ingredient: limoncello, Probability: 5.69407006878464e-07
# Ingredient: green chartreuse, Probability: 5.485520091497165e-07
# Ingredient: citron vodka, Probability: 4.528051817942469e-07
# Ingredient: grenadine, Probability: 4.4119323661107046e-07
# Ingredient: maraschino, Probability: 3.692141490319045e-07
# Ingredient: grapefruit juice, Probability: 3.3277365218964405e-07
# Ingredient: simple syrup, Probability: 1.964640290452735e-07
# Ingredient: orange twist, Probability: 1.7638978988543386e-07
# Ingredient: amontillado sherry, Probability: 1.7464630275298987e-07
# Ingredient: ginger, Probability: 1.573122148101902e-07
# Ingredient: mint, Probability: 1.4821600302639126e-07
# Ingredient: tequila, Probability: 1.4770351697279693e-07
# Ingredient: peach schnapps, Probability: 1.2286518824566883e-07
# Ingredient: angostura, Probability: 1.2277780570002506e-07
# Ingredient: mango juice, Probability: 1.13829223380435e-07
# Ingredient: soda water, Probability: 1.1244868858284462e-07
# Ingredient: rock candy syrup, Probability: 1.0191166666118079e-07
# Ingredient: egg yolk, Probability: 9.720380944600038e-08
# Ingredient: rhum barbancourt, Probability: 8.35819946587435e-08
# Ingredient: rose petals, Probability: 7.515241406963469e-08
# Ingredient: maraschino liqueur, Probability: 6.800340912604952e-08
# Ingredient: pineapple pieces, Probability: 6.281015885178931e-08
# Ingredient: pineapple rum, Probability: 6.097995708387316e-08
# Ingredient: tuaca, Probability: 5.3748156148003545e-08
# Ingredient: fernet branca, Probability: 4.6312688795069334e-08
# Ingredient: blue curaçao, Probability: 4.557868038546076e-08
# Ingredient: dry white wine, Probability: 4.5344819454840035e-08
# Ingredient: bonne maman raspberry preserves, Probability: 4.4755886108305276e-08
# Ingredient: vermouth, Probability: 4.25919104429795e-08
# Ingredient: gum syrup, Probability: 4.143824838820365e-08
# Ingredient: papaya slice, Probability: 4.085147864429928e-08
# Ingredient: peach bitters, Probability: 3.722074737311232e-08
# Ingredient: red port, Probability: 3.7159743726533634e-08
# Ingredient: banana, Probability: 2.9207877005887894e-08
# Ingredient: cola, Probability: 2.152922817799663e-08
# Ingredient: grand marnier, Probability: 1.913144487275531e-08
# Ingredient: ginger ale, Probability: 1.6512165856852334e-08
# Ingredient: diced ripe avocado, Probability: 1.558859175077032e-08
# Ingredient: lemon juice, Probability: 1.514342962138926e-08
# Ingredient: brandy, Probability: 1.3919204455703493e-08
# Ingredient: old tom gin, Probability: 1.2477380018083295e-08
# Ingredient: green crème de menthe, Probability: 1.0338213840555e-08
# Ingredient: marie brizard apry, Probability: 1.0028668562256371e-08
# Ingredient: vanilla syrup, Probability: 8.814520668920522e-09
# Ingredient: orgeat syrup, Probability: 8.51292458747821e-09
# Ingredient: cranberry juice, Probability: 8.00704302861277e-09
# Ingredient: creme de cacao, Probability: 7.74770647637979e-09
# Ingredient: rose water, Probability: 7.687516401233552e-09
# Ingredient: passion fruit syrup, Probability: 7.231139242946938e-09
# Ingredient: nutmeg, Probability: 6.949040454173883e-09
# Ingredient: absinth, Probability: 6.458996448799326e-09
# Ingredient: silver tequila, Probability: 6.257910190043958e-09
# Ingredient: chambord, Probability: 5.994081675453344e-09
# Ingredient: dolin rouge, Probability: 4.477183068729573e-09
# Ingredient: crème de cacao, Probability: 4.148322130248516e-09
# Ingredient: pimento dram, Probability: 3.6884260090630505e-09
# Ingredient: crushed ice, Probability: 3.6346723408797743e-09
# Ingredient: gold rum, Probability: 3.3023634937734414e-09
# Ingredient: raspberry syrup, Probability: 2.924772202206327e-09
# Ingredient: lemon wedge, Probability: 2.591021841524821e-09
# Ingredient: blackberries, Probability: 2.312251723424197e-09
# Ingredient: pineapple, Probability: 2.1332808852747576e-09
# Ingredient: black currant vodka, Probability: 1.942774385810253e-09
# Ingredient: b&b, Probability: 1.541237915070326e-09
# Ingredient: sloe gin, Probability: 1.5408322395771279e-09
# Ingredient: champagne, Probability: 1.527861948069642e-09
# Ingredient: crème de mûre, Probability: 1.3097292139718775e-09
# Ingredient: french garnier orgeat, Probability: 1.2205760846484282e-09
# Ingredient: blended whiskey, Probability: 1.1768698238157072e-09
# Ingredient: kosher salt, Probability: 1.1163758806276292e-09
# Ingredient: st. germain, Probability: 9.709699710924724e-10
# Ingredient: pineapple syrup, Probability: 8.575335996852118e-10
# Ingredient: triple sec, Probability: 7.473437424465601e-10
# Ingredient: crème de banane, Probability: 6.865602530936599e-10
# Ingredient: applejack, Probability: 6.513998784818398e-10
# Ingredient: orange flower water, Probability: 5.997727314799306e-10
# Ingredient: heavy cream, Probability: 5.688181592411468e-10
# Ingredient: chocolate bitters, Probability: 5.258070090441436e-10
# Ingredient: dry red wine, Probability: 5.134542790941055e-10
# Ingredient: orange bitters, Probability: 4.672941478212067e-10
# Ingredient: light rum, Probability: 4.5588632868742707e-10
# Ingredient: sugar, Probability: 4.524395580407514e-10
# Ingredient: whole strawberry, Probability: 4.335056202897647e-10
# Ingredient: half-and-half, Probability: 4.1515257898083746e-10
# Ingredient: watermelon juice, Probability: 4.0169947923551774e-10
# Ingredient: garnish with montmorency cherries, Probability: 4.0086675645589764e-10
# Ingredient: ron zacapa 23, Probability: 3.787483937589542e-10
# Ingredient: chopped green onion, Probability: 3.525384151270572e-10
# Ingredient: pineapple wedge, Probability: 3.4944952487236947e-10
# Ingredient: honey, Probability: 3.4745764598831386e-10
# Ingredient: nan, Probability: 3.362277400942304e-10
# Ingredient: spiced rum, Probability: 3.316570906797267e-10
# Ingredient: vanilla extract, Probability: 3.2685792961117954e-10
# Ingredient: cherry heering, Probability: 2.860492120948521e-10
# Ingredient: kahlua, Probability: 2.4815818844281523e-10
# Ingredient: absinthe, Probability: 2.3190786790916462e-10
# Ingredient: cachaça, Probability: 2.314332891995008e-10
# Ingredient: parts apple brandy, Probability: 2.3114962721670906e-10
# Ingredient: cranberries, Probability: 2.0463611360987954e-10
# Ingredient: orange liqueur, Probability: 2.040888569254662e-10
# Ingredient: black sambuca, Probability: 2.01143698919104e-10
# Ingredient: part grenadine, Probability: 1.9012544316687752e-10
# Ingredient: peach brandy, Probability: 1.8644311094995203e-10
# Ingredient: curacao, Probability: 1.843947355917308e-10
# Ingredient: light puerto rican rum, Probability: 1.7010422237451195e-10
# Ingredient: marie brizard creme de cacao, Probability: 1.6687520809632872e-10
# Ingredient: spearmint, Probability: 1.6506164490781572e-10
# Ingredient: raspberries, Probability: 1.6069887087688528e-10
# Ingredient: harveys bristol cream sherry, Probability: 1.5902765215791703e-10
# Ingredient: frozen raspberries, Probability: 1.4474468845726562e-10
# Ingredient: avocado slice, Probability: 1.413787420467827e-10
# Ingredient: gold tequila, Probability: 1.4057985331383804e-10
# Ingredient: dry vermouth, Probability: 1.2747509992028228e-10
# Ingredient: frangelico, Probability: 1.1065768440454704e-10
# Ingredient: glass spirit, Probability: 1.0668611133413108e-10
# Ingredient: 100 proof rhum agricole, Probability: 1.0333668643003335e-10
# Ingredient: salt, Probability: 1.0127305244411744e-10
# Ingredient: coconut sorbet , Probability: 9.24420817671745e-11
# Ingredient: yellow chartreuse, Probability: 8.351589558808215e-11
# Ingredient: pineapple juice, Probability: 8.015301616870474e-11
# Ingredient: tomato juice, Probability: 7.891894082678874e-11
# Ingredient: tonic water, Probability: 7.522702599738196e-11
# Ingredient: generic bitters, Probability: 7.166064963648466e-11
# Ingredient: apple juice, Probability: 7.026281639843646e-11
# Ingredient: orange cherry tomatoes, Probability: 7.013548075640585e-11
# Ingredient: turbinado syrup, Probability: 6.909595812176761e-11
# Ingredient: allspice dram, Probability: 6.767453264444612e-11
# Ingredient: peychauds, Probability: 5.881470310775683e-11
# Ingredient: pear brandy, Probability: 5.747155529256531e-11
# Ingredient: maraschino cherry, Probability: 5.32563125543728e-11
# Ingredient: white crème de menthe, Probability: 5.148553805511824e-11
# Ingredient: marachino, Probability: 4.16633359756613e-11
# Ingredient: water, Probability: 3.798188846770856e-11
# Ingredient: mango slice, Probability: 3.198822456917938e-11
# Ingredient: seltzer, Probability: 3.086809974295335e-11
# Ingredient: chopped cucumber, Probability: 3.076336060892082e-11
# Ingredient: green cocktail olive, Probability: 2.8663451820398755e-11
# Ingredient: parfait amour, Probability: 2.3290069525727652e-11
# Ingredient: gomme syrup, Probability: 2.160777112791834e-11
# Ingredient: sweet vermouth, Probability: 1.9859973041103096e-11
# Ingredient: worcestershire sauce, Probability: 1.9149742555568672e-11
# Ingredient: hot sauce, Probability: 1.7980974348352774e-11
# Ingredient: damiana liqueur, Probability: 1.6288947621290184e-11
# Ingredient: crme de menthe, Probability: 1.4821104413198505e-11
# Ingredient: midori liqueur, Probability: 1.344687729221139e-11
# Ingredient: pisco, Probability: 1.0963639718308826e-11
# Ingredient: coconut rum, Probability: 1.0877385797636308e-11
# Ingredient: shaved coconut, Probability: 1.0258293346721015e-11
# Ingredient: irish whiskey, Probability: 1.0257648029587951e-11
# Ingredient: lillet, Probability: 9.385983310017387e-12
# Ingredient: amaro nonino quintessentia, Probability: 8.451094858641373e-12
# Ingredient: blackberry liqueur, Probability: 8.413636107262867e-12
# Ingredient: single-malt scotch, Probability: 7.207416954924106e-12
# Ingredient: kina lillet, Probability: 6.484810518431194e-12
# Ingredient: ginger liqueur, Probability: 6.145553250319624e-12
# Ingredient: premium sake, Probability: 5.91849095774033e-12
# Ingredient: ginger-infused vodka, Probability: 4.661595328497858e-12
# Ingredient: small pat of soft butter, Probability: 4.460189162447392e-12
# Ingredient: pimms no. 1 cup, Probability: 4.2728030315297705e-12
# Ingredient: raw egg white, Probability: 4.1326313031386785e-12
# Ingredient: chocolate syrup, Probability: 3.96745830633094e-12
# Ingredient: elijah craig 12, Probability: 3.823342684117215e-12
# Ingredient: demerara syrup, Probability: 3.678121175687554e-12
# Ingredient: orgeat, Probability: 3.0053466226059866e-12
# Ingredient: prickly pear juice, Probability: 2.976373271110222e-12
# Ingredient: lillet blanc, Probability: 2.9714609679071247e-12
# Ingredient: orange slice, Probability: 2.7991387419740166e-12
# Ingredient: kirsch, Probability: 2.7803768402195894e-12
# Ingredient: pimm’s no. 1, Probability: 2.283331293137514e-12
# Ingredient: celery stalk, Probability: 2.1892882472174247e-12
# Ingredient: parts scotch, Probability: 2.1344169921083678e-12
# Ingredient: rye whiskey, Probability: 1.6242280957701194e-12
# Ingredient: ruby port, Probability: 1.4878679885366175e-12
# Ingredient: sweet cream, Probability: 1.4179988563553514e-12
# Ingredient: torani amer, Probability: 1.3724593293448772e-12
# Ingredient: kahlúa, Probability: 1.3480845129434926e-12
# Ingredient: crème de violette, Probability: 1.2187851639380853e-12
# Ingredient: cubed ripe papaya, Probability: 1.2025266849999272e-12
# Ingredient: crème de framboise, Probability: 1.105189832879827e-12
# Ingredient: curaao, Probability: 1.0370284275404429e-12
# Ingredient: sweetened ginger juice, Probability: 1.0164119979699793e-12
# Ingredient: hot water, Probability: 1.0108421261492695e-12
# Ingredient: mari brizard white creme de cacao, Probability: 9.517578782383684e-13
# Ingredient: cognac, Probability: 9.459610829029574e-13
# Ingredient: apple schnapps, Probability: 8.855231543695996e-13
# Ingredient: vodka, Probability: 8.183785680376809e-13
# Ingredient: ground nutmeg, Probability: 8.121973146119066e-13
# Ingredient: mezcal, Probability: 7.993476215141515e-13
# Ingredient: oaxacan chocolate powder, Probability: 7.975749509621377e-13
# Ingredient: dubonnet rouge, Probability: 7.134050294954619e-13
# Ingredient: velvet falernum, Probability: 6.719341879776741e-13
# Ingredient: limoncello liqueur, Probability: 6.618272553257643e-13
# Ingredient: aperol, Probability: 6.047064433391258e-13
# Ingredient: seeded, peeled, cubed papaya, Probability: 5.52018446144803e-13
# Ingredient: dark rum, Probability: 5.504077553973585e-13
# Ingredient: grated nutmeg, Probability: 5.371624911369721e-13
# Ingredient: agave nectar, Probability: 5.332191394154251e-13
# Ingredient: banana slice, Probability: 5.292846239415838e-13
# Ingredient: milk, Probability: 4.810843021695044e-13
# Ingredient: butterscotch schnapps, Probability: 4.191916453712141e-13
# Ingredient: tia maria coffee liqueur, Probability: 4.0938579566260347e-13
# Ingredient: pastis, Probability: 4.0198706451229083e-13
# Ingredient: whiskey, Probability: 3.915240798669367e-13
# Ingredient: black olive, Probability: 3.8215256154862376e-13
# Ingredient: 7-up, Probability: 3.671888097397935e-13
# Ingredient: english cucumber, Probability: 3.558501963148858e-13
# Ingredient: watermelon, Probability: 3.1409898011529325e-13
# Ingredient: cucumber slices, Probability: 3.0670878705708893e-13
# Ingredient: blended scotch, Probability: 2.7061225439314884e-13
# Ingredient: large eggs, Probability: 2.2370664619787012e-13
# Ingredient: orange-flavored vodka, Probability: 2.0942708016998685e-13
# Ingredient: drambuie, Probability: 1.6804106391966889e-13
# Ingredient: scotch whiskey, Probability: 1.6545854855491704e-13
# Ingredient: rothman & winter orchard apricot, Probability: 1.5781000367153658e-13
# Ingredient: bénédictine, Probability: 1.4161627870813015e-13
# Ingredient: godiva liqueur, Probability: 1.3717152413939004e-13
# Ingredient: 99 bananas liqueur, Probability: 1.2623318460403682e-13
# Ingredient: ground cinnamon, Probability: 1.2590040229971955e-13
# Ingredient: dry sake, Probability: 1.2461650363958937e-13
# Ingredient: white crème de cacao, Probability: 1.2193495995890813e-13
# Ingredient: plum wine, Probability: 9.892389370765725e-14
# Ingredient: minced clove garlic, Probability: 9.494003348244073e-14
# Ingredient: vanilla-flavored vodka, Probability: 9.151564868328105e-14
# Ingredient: tangerine juice, Probability: 8.737398960812284e-14
# Ingredient: passion fruit juice, Probability: 8.710127210416127e-14
# Ingredient: coconut milk, Probability: 7.161900060633983e-14
# Ingredient: lime sorbet, Probability: 6.751481426876815e-14
# Ingredient: makers mark, Probability: 6.469299515575802e-14
# Ingredient: splash of soda water, Probability: 6.047488627491243e-14
# Ingredient: lazzaroni amaretto, Probability: 5.0783829859445476e-14
# Ingredient: strawberry, Probability: 4.7396080929320433e-14
# Ingredient: maraschino liquor, Probability: 3.9448401278419434e-14
# Ingredient: amer picon, Probability: 3.227142335369797e-14
# Ingredient: selected liquor, Probability: 3.213855776559166e-14
# Ingredient: southern comfort, Probability: 2.5762856068313814e-14
# Ingredient: pear liqueur, Probability: 2.4344606124287842e-14
# Ingredient: cucumber spear, Probability: 2.134907410632301e-14
# Ingredient: punt e mes, Probability: 1.9825121226743278e-14
# Ingredient: strawberry syrup, Probability: 1.8896131065578546e-14
# Ingredient: compass box asyla scotch, Probability: 1.6824495152633658e-14
# Ingredient: egg white, beaten, Probability: 1.382338711677705e-14
# Ingredient: sambuca, Probability: 1.3615513373059582e-14
# Ingredient: whole milk, Probability: 1.3281604514922465e-14
# Ingredient: purple grape juice, Probability: 1.3188707023465297e-14
# Ingredient: sweet-and-sour, Probability: 1.0971759220287144e-14
# Ingredient: bourbon whiskey, Probability: 9.008990757986956e-15
# Ingredient: fuji apple slices, Probability: 8.7719765397851e-15
# Ingredient: vodka citron, Probability: 8.593357619999901e-15
# Ingredient: mandarin  juice, Probability: 6.737314462020808e-15
# Ingredient: melon liqueur, Probability: 6.405143715491456e-15
# Ingredient: jägermeister, Probability: 5.88796869130403e-15
# Ingredient: coconut cream, Probability: 5.139634140646169e-15
# Ingredient: vieux pontarlier absinthe, Probability: 4.971082630955562e-15
# Ingredient: root beer schnapps, Probability: 4.862415503602887e-15
# Ingredient: absinthe substitute, Probability: 4.7752850359671e-15
# Ingredient: creme de violette/yvette, Probability: 4.268894858780589e-15
# Ingredient: egg whites, Probability: 4.195263555225193e-15
# Ingredient: apple brandy, Probability: 4.184267373503938e-15
# Ingredient: cold coffee, Probability: 4.13775975898552e-15
# Ingredient: maple syrup, Probability: 3.957913911976224e-15
# Ingredient: peychaud’s bitters, Probability: 3.448415970906237e-15
# Ingredient: crème de noyaux, Probability: 2.411619691379714e-15
# Ingredient: pierre ferrand ambre cognac, Probability: 2.3667616735260737e-15
# Ingredient: strong black coffee, Probability: 2.2005005409248424e-15
# Ingredient: prosecco, Probability: 1.870863269940728e-15
# Ingredient: glass chartreuse, Probability: 1.440439454386956e-15
# Ingredient: lumps of ice, Probability: 1.1952782615401707e-15
# Ingredient: nectarine slice, Probability: 1.1145639626007164e-15
# Ingredient: splash soda, Probability: 1.0073049216437332e-15
# Ingredient: tangerine beverage, Probability: 9.254769861368763e-16
# Ingredient: lairds bonded apple brandy, Probability: 8.517246627491419e-16
# Ingredient: chocolate liqueur, Probability: 7.980210798273248e-16
# Ingredient: luxardo maraschino liqueur, Probability: 7.104708014870546e-16
# Ingredient: st. george nola coffee liqueur, Probability: 6.537502989653545e-16
# Ingredient: maraschino cherries, Probability: 5.78499521354368e-16
# Ingredient: sliced, hulled strawberries, Probability: 5.657780393986741e-16
# Ingredient: cane syrup, Probability: 5.013395314802703e-16
# Ingredient: walnut liqueur, Probability: 4.777359525534044e-16
# Ingredient: apricot liqueur, Probability: 4.2166483313467267e-16
# Ingredient: range blossom, Probability: 4.1022856485775953e-16
# Ingredient: freshly cracked pepper, Probability: 3.683653113984754e-16
# Ingredient: tia maria, Probability: 3.0542517829398495e-16
# Ingredient: pernod, Probability: 2.483894471670082e-16
# Ingredient: maraschino cherry juice, Probability: 2.231173986225085e-16
# Ingredient: wasabi, Probability: 1.8953360105505954e-16
# Ingredient: bittermens xocolatl mole bitters, Probability: 1.706893546750277e-16
# Ingredient: mandarine napoléon liqueur, Probability: 1.4213455053410515e-16
# Ingredient: bacardi cups, Probability: 1.3817256715821296e-16
# Ingredient: jigger sazerac brandy, Probability: 1.2879296105168227e-16
# Ingredient: peach slice, Probability: 1.0983264468809699e-16
# Ingredient: bigallet china china amer, Probability: 9.4586356039985e-17
# Ingredient: coffee liqueur, Probability: 9.135994136944437e-17
# Ingredient: highland malt scotch, Probability: 6.434402404011547e-17
# Ingredient: sweet marsala, Probability: 6.352917172741193e-17
# Ingredient: liquor, Probability: 4.040085769329446e-17
# Ingredient: crème de menthe, Probability: 3.915561338171223e-17
# Ingredient: lager, Probability: 3.122758021003654e-17
# Ingredient: dolin blanc, Probability: 2.465879999941004e-17
# Ingredient: watermelon wedge, Probability: 2.454908110859978e-17
# Ingredient: bokers bitters, Probability: 2.388180939770428e-17
# Ingredient: soy sauce, Probability: 2.02440427716247e-17
# Ingredient: kassatly chtaura orgeat, Probability: 1.870597321447625e-17
# Ingredient: banana liqueur, Probability: 1.2870400108552464e-17
# Ingredient: peppermint schnapps, Probability: 1.2226284491724772e-17
# Ingredient: midori, Probability: 7.574810506503295e-18
# Ingredient: genever, Probability: 7.393386637113264e-18
# Ingredient: brown crème de cacao, Probability: 7.178775454366994e-18
# Ingredient: averna amaro, Probability: 6.250461672171702e-18
# Ingredient: egg, Probability: 5.736424342571036e-18
# Ingredient: disaronno, Probability: 5.231748215962633e-18
# Ingredient: tangerine slice, Probability: 4.0802755801612535e-18
# Ingredient: chocolate shavings, Probability: 3.609302100430711e-18
# Ingredient: vanilla bean, Probability: 3.4062470444321127e-18
# Ingredient: sherry, Probability: 3.039151526411439e-18
# Ingredient: herbsaint, Probability: 2.596194240437761e-18
# Ingredient: diced onion, Probability: 2.2602294579753673e-18
# Ingredient: baileys, Probability: 1.8973161651317616e-18
# Ingredient: unsweetened cocoa powder, Probability: 1.7040942186648873e-18
# Ingredient: cucumber peel strip, Probability: 1.4027392934171716e-18
# Ingredient: baileys irish cream, Probability: 1.330434608893299e-18
# Ingredient: diced jalapeño chile, Probability: 1.101883985259438e-18
# Ingredient: cognac , Probability: 8.561829606964205e-19
# Ingredient: st. elizabeth allspice dram, Probability: 8.195287782966059e-19
# Ingredient: kümmel, Probability: 6.164432200129196e-19
# Ingredient: spring water, Probability: 6.014310292684244e-19
# Ingredient: fernet-branca, Probability: 5.864442226289769e-19
# Ingredient: port, Probability: 5.649425931838501e-19
# Ingredient: add 3 oz. club soda, Probability: 5.076220269624341e-19
# Ingredient: spirits, Probability: 5.007023509456983e-19
# Ingredient: add sherry and juices, Probability: 4.376459075616864e-19
# Ingredient: cinnamon stick, Probability: 4.1189166503924205e-19
# Ingredient: cinnamon, Probability: 3.8008545896263e-19
# Ingredient: apple cider, Probability: 3.7776544998896606e-19
# Ingredient: ice cream, Probability: 3.434414870735016e-19
# Ingredient: rothman & winter creme de violette, Probability: 3.1948095985998433e-19
# Ingredient: fruit, Probability: 2.9701641463366335e-19
# Ingredient: goldschläger cinnamon schnapps, Probability: 2.3965014668340376e-19
# Ingredient: hine h cognac, Probability: 2.209824897156719e-19
# Ingredient: cabernet sauvignon, Probability: 1.7733561968536661e-19
# Ingredient: thai coconut milk, Probability: 1.730446978059302e-19
# Ingredient: amaro nonino, Probability: 1.5095357292738863e-19
# Ingredient: lustau amontillado sherry, Probability: 1.3599803113015625e-19
# Ingredient: strawberry liqueur, Probability: 1.134244660840402e-19
# Ingredient: amber martinician rhum, Probability: 9.556071234943622e-20
# Ingredient: al wadi pomegranate molasses, Probability: 5.892200081201576e-20
# Ingredient: chai, Probability: 5.716670416513263e-20
# Ingredient: edible flower, Probability: 5.3778798558314173e-20
# Ingredient: medium sherry, Probability: 5.061077759159277e-20
# Ingredient: splash of club soda, Probability: 4.9629983723174965e-20
# Ingredient: cold espresso, Probability: 4.5415346637026703e-20
# Ingredient: amaretto, Probability: 1.4694343362947423e-20
# Ingredient: instant coffee, Probability: 1.3651149057070147e-20
# Ingredient: small orchid, Probability: 6.0046300823188715e-21
# Ingredient: ruby fizz, Probability: 2.3545435622896593e-21
# Ingredient: scotch, Probability: 1.533534088691318e-21
# Ingredient: dark crème de cacao, Probability: 1.281369411813913e-21
# Ingredient: remy martin vsop cognac, Probability: 1.9716362849116426e-22
# Ingredient: jalapeño chile slice, Probability: 3.8699319821382704e-23

# %% [markdown]
# Summary of Steps:
# Clean Data Preparation:
#
# Create a DataFrame with binary encoded ingredient vectors for each recipe.
# Model Building:
#
# Define a neural network to learn from these vectors.
# Model Training:
#
# Train the model on your dataset.
# Recipe Generation:
#
# Generate new recipes starting from seed ingredients.
# By following these steps, you should be able to create and train a model that can generate new cocktail recipes based on the patterns it learns from your dataset. Let me know if you need more detail on any of these steps!

# %% [markdown]
# The architecture described here is a simple feedforward neural network, also known as a Multi-Layer Perceptron (MLP). This architecture is used for multi-label classification, where each ingredient is treated as a binary label that can be present or absent in a recipe.
#
# Architecture Explanation
# Input Layer:
#
# The input layer consists of nodes equal to the number of unique ingredients. Each node represents whether a particular ingredient is present (1) or absent (0) in the recipe.
# Input Dimension: input_dim = len(all_ingredients).
# Hidden Layers:
#
# The network has two hidden layers, each with 128 neurons. These layers use the ReLU (Rectified Linear Unit) activation function, which introduces non-linearity to the model and allows it to learn complex patterns.
# First Hidden Layer: Dense(units=128, input_dim=input_dim, activation='relu')
# Second Hidden Layer: Dense(units=128, activation='relu')
# Output Layer:
#
# The output layer also consists of nodes equal to the number of unique ingredients. Each node represents the probability of the corresponding ingredient being part of the recipe.
# The sigmoid activation function is used in the output layer to produce probabilities between 0 and 1 for each ingredient.
# Output Layer: Dense(units=input_dim, activation='sigmoid')
# Loss Function:
#
# The model uses binary cross-entropy loss, suitable for multi-label classification where each label (ingredient) is a binary decision (present or absent).
# Loss Function: binary_crossentropy
# Optimizer:
#
# The Adam optimizer is used to minimize the loss function during training. Adam is a popular choice due to its adaptive learning rate and efficiency.
# Optimizer: adam
# Metrics:
#
# The accuracy metric is used to evaluate the model's performance during training and validation.
# Metrics: accuracy
# Why This Architecture?
# Simplicity: This architecture is straightforward and easy to implement, making it suitable for a dataset of your size (654 recipes and 447 unique ingredients).
# Flexibility: The use of dense layers allows the network to learn from the presence and absence of each ingredient, capturing the relationships between different ingredients.
# Scalability: Adding more hidden layers or increasing the number of neurons in each layer can improve the model's capacity to learn more complex patterns, if needed.
# Summary
# This architecture is a feedforward neural network designed for multi-label classification. It takes a binary vector representing the presence or absence of each ingredient as input and outputs a binary vector representing the predicted probabilities of each ingredient being part of the cocktail recipe. This approach is suitable for generating new recipes by learning the common ingredient combinations from the training data.

# %% [markdown]
# ## Next chunk of code: Randomly decides to include this ingredient based on its probability

# %%
import numpy as np
from collections import Counter
import pandas as pd

# Assuming `predicted_probabilities` is already defined and is a 2D array
# and `mlb` is your MultiLabelBinarizer instance

def generate_semi_random_cocktail(predicted_probabilities, mlb, top_n=10, threshold=0.05):
    # Ensure predicted_probabilities is 2D
    if predicted_probabilities.ndim == 1:
        predicted_probabilities = predicted_probabilities.reshape(1, -1)
    
    # Get the indices that would sort each row of the array in descending order
    sorted_indices = np.argsort(-predicted_probabilities, axis=1)
    
    # Get the sorted probabilities
    sorted_probabilities = np.take_along_axis(predicted_probabilities, sorted_indices, axis=1)

    # For each row, map the sorted indices back to the ingredient names
    # Assuming you want to do this for the first row in the predictions
    top_ingredients_indices = sorted_indices[0]
    top_probabilities = sorted_probabilities[0]

    # Map these indices back to the ingredient names
    top_ingredients = mlb.classes_[top_ingredients_indices]

    # Semi-random selection based on sorted probabilities
    selected_ingredients = []
    for i in range(top_n):
        if top_probabilities[i] > threshold:
            # Randomly decide to include this ingredient based on its probability
            if (np.random.random() * 0.1) < top_probabilities[i]:
                selected_ingredients.append(top_ingredients[i])
    
    return selected_ingredients

# Number of times to generate recipes
num_iterations = 100

# Example seed ingredients
seed_ingredients = ['gin', 'lime juice']
seed_vector = mlb.transform([seed_ingredients])[0]

# List to store generated recipes
generated_recipes = []

for _ in range(num_iterations):
    # Fit the model for one epoch
    model.fit(X, y, epochs=1, batch_size=389, validation_split=0.2, verbose=0)
    
    # Predict probabilities
    predicted_probabilities = model.predict(seed_vector.reshape(1, -1))
    
    # Generate recipe using the semi-random selection method
    generated_recipe = generate_semi_random_cocktail(predicted_probabilities, mlb, top_n=10, threshold=0.000000005)
    
    # Add the seed ingredients to ensure they are included
    full_recipe = list(set(seed_ingredients + generated_recipe))
    
    # Store the generated recipe as a tuple for easier counting
    generated_recipes.append(tuple(full_recipe))

# Count the occurrences of each unique recipe
recipe_counts = Counter(generated_recipes)

# Convert to DataFrame
df = pd.DataFrame(recipe_counts.items(), columns=['Recipe', 'Count'])

# Sort by count (optional)
df = df.sort_values(by='Count', ascending=False)

print(df)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
df

# %%
all_ingredients[1]

# %%
print("Predicted Probabilities:", predicted_probabilities)

# %%
predicted_probabilities[86]
